# %% [markdown]
# <a href="https://colab.research.google.com/github/LEO690201/Artificial-neural-network/blob/LeNet-5/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --branch LeNet-5 https://github.com/LEO690201/Artificial-neural-network.git
# Out:
# Cloning into 'Artificial-neural-network'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 20 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 382.22 KiB | 12.33 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
import os
os.chdir('Artificial-neural-network/')

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 30.8 MB/s eta 0:00:00
# ...

# %%
# !find / -name virtualenv
# Out:
# /usr/local/bin/virtualenv
# /usr/local/lib/python3.11/dist-packages/virtualenv
# /root/.local/share/virtualenv
# find: ‘/proc/68/task/68/net’: Invalid argument
# find: ‘/proc/68/net’: Invalid argument
# /tools/google-cloud-sdk/lib/googlecloudsdk/command_lib/config/virtualenv
# /tools/google-cloud-sdk/lib/surface/config/virtualenv

# %%
# !/usr/local/bin/virtualenv venv
# Out:
# created virtual environment CPython3.11.11.final.0-64 in 910ms
#   creator CPython3Posix(dest=/content/Artificial-neural-network/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.0.1, setuptools==75.8.0, wheel==0.45.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !cd venv

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.5 MB/s eta 0:00:00
# ...
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement torch==2.6.0+cpu (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0)
# ERROR: No matching distribution found for torch==2.6.0+cpu

# %%
# !python model.py
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1            [-1, 6, 28, 28]             156
#            Sigmoid-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#            Sigmoid-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#            Flatten-7                  [-1, 400]               0
#             Linear-8                  [-1, 120]          48,120
#             Linear-9                   [-1, 84]          10,164
#            Linear-10                   [-1, 10]             850
# ...
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# ...

# %%
# !python plot.py
# Out:
# 100% 26.4M/26.4M [00:02<00:00, 11.3MB/s]
# 100% 29.5k/29.5k [00:00<00:00, 166kB/s]
# 100% 4.42M/4.42M [00:01<00:00, 3.08MB/s]
# 100% 5.15k/5.15k [00:00<00:00, 33.3MB/s]
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# Figure(1200x500)

# %%
# !python model_train.py
# Out:
# Epoch 1/50
# ----------
# 0Train Loss: 0.8871  Train Acc: 0.6582
# 0Val Loss: 0.6411 Vac Acc: 0.7611
# 训练耗时0m15s
# Epoch 2/50
# ----------
# 1Train Loss: 0.5829  Train Acc: 0.7762
# 1Val Loss: 0.5017 Vac Acc: 0.8148
# 训练耗时0m30s
# Epoch 3/50
# ----------
# 2Train Loss: 0.5029  Train Acc: 0.8149
# 2Val Loss: 0.4921 Vac Acc: 0.8096
# 训练耗时0m45s
# Epoch 4/50
# ----------
# 3Train Loss: 0.4679  Train Acc: 0.8269
# 3Val Loss: 0.4759 Vac Acc: 0.8237
# 训练耗时1m2s
# Epoch 5/50
# ----------
# 4Train Loss: 0.4444  Train Acc: 0.8369
# 4Val Loss: 0.4419 Vac Acc: 0.8413
# 训练耗时1m19s
# Epoch 6/50
# ----------
# 5Train Loss: 0.4283  Train Acc: 0.8440
# 5Val Loss: 0.4201 Vac Acc: 0.8489
# 训练耗时1m38s
# Epoch 7/50
# ----------
# 6Train Loss: 0.4115  Train Acc: 0.8510
# 6Val Loss: 0.3968 Vac Acc: 0.8551
# 训练耗时1m52s
# Epoch 8/50
# ----------
# 7Train Loss: 0.4003  Train Acc: 0.8526
# 7Val Loss: 0.4024 Vac Acc: 0.8540
# 训练耗时2m8s
# Epoch 9/50
# ----------
# 8Train Loss: 0.3873  Train Acc: 0.8589
# ...

# %%
# !python model_test.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 预测值：  T-shirt/top ~~~~~~ 真实值：  T-shirt/top
# 预测值：  Dress ~~~~~~ 真实值：  T-shirt/top
# 预测值：  Coat ~~~~~~ 真实值：  Coat
# 预测值：  Shirt ~~~~~~ 真实值：  T-shirt/top
# 预测值：  Shirt ~~~~~~ 真实值：  Coat
# 预测值：  Ankle boot ~~~~~~ 真实值：  Ankle boot
# 预测值：  T-shirt/top ~~~~~~ 真实值：  T-shirt/top
# 预测值：  Coat ~~~~~~ 真实值：  Coat
# 预测值：  T-shirt/top ~~~~~~ 真实值：  Shirt
# 预测值：  Dress ~~~~~~ 真实值：  Dress
# 预测值：  Dress ~~~~~~ 真实值：  Shirt
# 预测值：  Ankle boot ~~~~~~ 真实值：  Ankle boot
# 预测值：  Sandal ~~~~~~ 真实值：  Sandal
# 预测值：  Coat ~~~~~~ 真实值：  Coat
# 预测值：  Trouser ~~~~~~ 真实值：  Trouser
# 预测值：  Pullover ~~~~~~ 真实值：  Pullover
# 预测值：  Pullover ~~~~~~ 真实值：  Coat
# 预测值：  Shirt ~~~~~~ 真实值：  Shirt
# 预测值：  Bag ~~~~~~ 真实值：  Bag
# 预测值：  Pullover ~~~~~~ 真实值：  Coat
# 预测值：  Dress ~~~~~~ 真实值：  Dress
# 预测值：  Bag ~~~~~~ 真实值：  Bag
# 预测值：  Ankle boot ~~~~~~ 真实值：  Ankle boot
# 预测值：  Shirt ~~~~~~ 真实值：  Shirt
# 预测值：  Sandal ~~~~~~ 真实值：  Sandal
# 预测值：  T-shirt/top ~~~~~~ 真实值：  T-shirt/top
# ...

# %%
# !python model_test_my_photo.py
# Out:
# 预测的标签为：包，标签序号为：8
